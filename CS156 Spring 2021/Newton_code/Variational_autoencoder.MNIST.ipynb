# %% [markdown]
# # This notebook shows implementation of a variational autoencoder with convolution kernels to generate new images

# %% [markdown]
# The network architechture in this example comes from here: https://keras.io/examples/generative/vae/

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %% [markdown]
# ## Load and prepare MNIST data

# %%
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train_valid, y_train_valid), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train.shape, x_test.shape
# Out:
# ((48000, 28, 28), (12000, 28, 28), (10000, 28, 28))

# %%
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

x_train.shape, x_test.shape
# Out:
# ((48000, 28, 28, 1), (12000, 28, 28, 1), (10000, 28, 28, 1))

# %% [markdown]
# ## Build the model architecture

# %% [markdown]
# #### Sampling layer

# %%
class Sampling(layers.Layer):   #this is how you do inheritence in python (this class is a child of layers.Layer)
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# #### Encoder

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 14, 14, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 64)     18496       conv2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           50192       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            34          dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            34          dense[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 2)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 69,076
# Trainable params: 69,076
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 32)        18464
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 1)         289
# =================================================================
# Total params: 65,089
# Trainable params: 65,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### VAE model

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = encoder(data)
            reconstruction = decoder(z)
            reconstruction_loss = tf.reduce_mean(
                keras.losses.binary_crossentropy(data, reconstruction)
            )
            reconstruction_loss *= 28 * 28
            kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            kl_loss = tf.reduce_mean(kl_loss)
            kl_loss *= -0.5
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# %% [markdown]
# ## Train the model

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(x_train, epochs=30, batch_size=2048)
# Out:
# Epoch 1/30
# 24/24 [==============================] - 18s 745ms/step - loss: 216.4751 - reconstruction_loss: 216.4696 - kl_loss: 0.0055
# Epoch 2/30
# 24/24 [==============================] - 18s 756ms/step - loss: 208.3960 - reconstruction_loss: 207.8927 - kl_loss: 0.5033
# Epoch 3/30
# 24/24 [==============================] - 19s 778ms/step - loss: 203.8872 - reconstruction_loss: 202.4576 - kl_loss: 1.4296
# Epoch 4/30
# 24/24 [==============================] - 18s 770ms/step - loss: 201.8954 - reconstruction_loss: 200.0768 - kl_loss: 1.8187
# Epoch 5/30
# 24/24 [==============================] - 21s 883ms/step - loss: 199.9824 - reconstruction_loss: 197.7764 - kl_loss: 2.2060
# Epoch 6/30
# 24/24 [==============================] - 27s 1s/step - loss: 198.0899 - reconstruction_loss: 195.5331 - kl_loss: 2.5568
# Epoch 7/30
# 24/24 [==============================] - 24s 996ms/step - loss: 195.7908 - reconstruction_loss: 193.1315 - kl_loss: 2.6593
# Epoch 8/30
# 24/24 [==============================] - 23s 968ms/step - loss: 193.4088 - reconstruction_loss: 190.7340 - kl_loss: 2.6748
# Epoch 9/30
# 24/24 [==============================] - 22s 937ms/step - loss: 191.8726 - reconstruction_loss: 189.2443 - kl_loss: 2.6283
# Epoch 10/30
# 24/24 [==============================] - 23s 940ms/step - loss: 190.4405 - reconstruction_loss: 187.8488 - kl_loss: 2.5917
# Epoch 11/30
# 24/24 [==============================] - 23s 968ms/step - loss: 189.4974 - reconstruction_loss: 186.9430 - kl_loss: 2.5543
# Epoch 12/30
# 24/24 [==============================] - 23s 955ms/step - loss: 188.4684 - reconstruction_loss: 185.9323 - kl_loss: 2.5361
# Epoch 13/30
# 24/24 [==============================] - 23s 961ms/step - loss: 187.7801 - reconstruction_loss: 185.2428 - kl_loss: 2.5373
# Epoch 14/30
# 24/24 [==============================] - 22s 926ms/step - loss: 186.9407 - reconstruction_loss: 184.3948 - kl_loss: 2.5459
# Epoch 15/30
# 24/24 [==============================] - 21s 893ms/step - loss: 186.1639 - reconstruction_loss: 183.6399 - kl_loss: 2.5240
# Epoch 16/30
# 24/24 [==============================] - 22s 931ms/step - loss: 185.8626 - reconstruction_loss: 183.3303 - kl_loss: 2.5324
# Epoch 17/30
# 24/24 [==============================] - 23s 950ms/step - loss: 185.3267 - reconstruction_loss: 182.8164 - kl_loss: 2.5104
# Epoch 18/30
# 24/24 [==============================] - 24s 996ms/step - loss: 184.8439 - reconstruction_loss: 182.3375 - kl_loss: 2.5064
# Epoch 19/30
# 24/24 [==============================] - 23s 952ms/step - loss: 184.5887 - reconstruction_loss: 182.0879 - kl_loss: 2.5009
# Epoch 20/30
# 24/24 [==============================] - 23s 943ms/step - loss: 184.2463 - reconstruction_loss: 181.7483 - kl_loss: 2.4980
# Epoch 21/30
# 24/24 [==============================] - 22s 904ms/step - loss: 184.2153 - reconstruction_loss: 181.7331 - kl_loss: 2.4822
# Epoch 22/30
# 24/24 [==============================] - 23s 945ms/step - loss: 183.6143 - reconstruction_loss: 181.1522 - kl_loss: 2.4622
# Epoch 23/30
# 24/24 [==============================] - 23s 957ms/step - loss: 183.2237 - reconstruction_loss: 180.7578 - kl_loss: 2.4659
# Epoch 24/30
# 24/24 [==============================] - 24s 994ms/step - loss: 183.0544 - reconstruction_loss: 180.5910 - kl_loss: 2.4634
# Epoch 25/30
# 24/24 [==============================] - 23s 952ms/step - loss: 182.9925 - reconstruction_loss: 180.5364 - kl_loss: 2.4562
# Epoch 26/30
# 24/24 [==============================] - 21s 890ms/step - loss: 182.5395 - reconstruction_loss: 180.0838 - kl_loss: 2.4558
# Epoch 27/30
# 24/24 [==============================] - 22s 897ms/step - loss: 182.7091 - reconstruction_loss: 180.2576 - kl_loss: 2.4515
# Epoch 28/30
# 24/24 [==============================] - 22s 912ms/step - loss: 182.3900 - reconstruction_loss: 179.9547 - kl_loss: 2.4353
# Epoch 29/30
# 24/24 [==============================] - 23s 963ms/step - loss: 182.2522 - reconstruction_loss: 179.8272 - kl_loss: 2.4250
# Epoch 30/30
# 24/24 [==============================] - 23s 940ms/step - loss: 182.1109 - reconstruction_loss: 179.6986 - kl_loss: 2.4122

# %% [markdown]
# ## Sample digits from the latent space

# %%
def plot_latent(encoder, decoder):
    # display a n*n 2D manifold of digits
    n = 30
    digit_size = 28
    scale = 2.0
    figsize = 15
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range + 1
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent(encoder, decoder)
